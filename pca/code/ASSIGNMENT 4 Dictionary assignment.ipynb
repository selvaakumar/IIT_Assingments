# %% [markdown]
# Q1.
# What is a dictionary in Python?
# Dictonary is variable to  store value in KEY and value format.

# %% [markdown]
# Q2.
# Create a dictionary to store the following student information:
# Name: John
# Age: 21
# Department: CSE

# %%
student = {"Name": "John",
     "Age" : 21,
     "Department" : "CSE"}
print(student)
# Out:
# {'Name': 'John', 'Age': 21, 'Department': 'CSE'}

# %% [markdown]
# Q3.
# How do you access the value of a key named "Age"?

# %%
print(student["Age"])
# Out:
# 21

# %% [markdown]
# Q4. What happens if you access a key that does not exist?
# Example:
# student["Marks"]
# will get keyerror

# %%
student["Marks"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 student["Marks"]
#
# KeyError: 'Marks'

# %% [markdown]
# Q5.
# What is the difference between
# student["Age"]
# and
# student.get("Age")
#
# student["Age"] is direct access if key not exist throw keyerror
# student.get("Age")  if key not exist will get None

# %% [markdown]
# Q6.
# Write a program to print all keys of a dictionary.

# %%
for i in student.keys():
    print(i)
# Out:
# Name
# Age
# Department

# %% [markdown]
# Q7.
# Write a program to print all values.

# %%
for i in student.values():
    print(i)
# Out:
# John
# 21
# CSE

# %% [markdown]
# Q8.
# Write a program to print all key-value pairs.

# %%
for i in student.items():
    print(i)
# Out:
# ('Name', 'John')
# ('Age', 21)
# ('Department', 'CSE')

# %% [markdown]
# Q9.
# How do you check whether a key exists in a dictionary?

# %%
if "Age" in student:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# Q10.
# How do you find the number of items in a dictionary?

# %%
print(len(student))
# Out:
# 3

# %% [markdown]
# Q11.
# Add a new key

# %%
student["Mark"] = 90
print(student)
# Out:
# {'Name': 'John', 'Age': 21, 'Department': 'CSE', 'Mark': 90}

# %% [markdown]
# Q12.
# Update the age from 21 to 22.

# %%
student.update({"Age" : 22}) 
print(student)
# Out:
# {'Name': 'John', 'Age': 22, 'Department': 'CSE', 'Mark': 90}

# %% [markdown]
# Q13.
# Delete the key "Department".

# %%
student.pop("Department")
print(student)
# Out:
# {'Name': 'John', 'Age': 21}

# %% [markdown]
# Q14.
# Remove the last inserted key-value pair.

# %%
student.popitem()
print(student)
# Out:
# {'Name': 'John'}

# %% [markdown]
# Q15.
# Clear the entire dictionary.

# %%
student.clear()
print(student)
# Out:
# {}

# %% [markdown]
# Q16.
# Create a dictionary using two lists.
# Example:
# keys = ["A","B","C"]
# values = [10,20,30]

# %%
keys = ["A","B","C"]
values = [10,20,30]
dic = dict(zip(keys,values))
print(dic)
# Out:
# {'A': 10, 'B': 20, 'C': 30}

# %% [markdown]
# Q17.
# Merge two dictionaries.

# %%
dict1 = {
    "A": 10,
    "B": 20
}

dict2 = {
    "C": 30,
    "D": 40
}

dict1.update(dict2)

print(dict1)
# Out:
# {'A': 10, 'B': 20, 'C': 30, 'D': 40}

# %% [markdown]
# Q18.
# Copy one dictionary into another.

# %%
dict3 = dict1.copy()
print(dict3)
# Out:
# {'A': 10, 'B': 20, 'C': 30, 'D': 40}

# %% [markdown]
# Q19.
# Find the maximum value stored in a dictionary.
# Example:
# marks={
# "A":85,
# "B":92,
# "C":76
# }

# %%
marks={
"A":85,
"B":92,
"C":76
}
print(max(marks.values()))
# Out:
# 92

# %% [markdown]
# Q20.
# Find the student who scored the highest marks.
# Expected output
# B scored 92

# %%
highest = max(marks, key=marks.get)

print(highest, "scored", marks[highest])
# Out:
# B scored 92

# %% [markdown]
# Q21.
# Print only the keys.

# %%
print(marks.keys())
# Out:
# dict_keys(['A', 'B', 'C'])

# %% [markdown]
# Q22.
# Print only the values.

# %%
print(marks.values())
# Out:
# dict_values([85, 92, 76])

# %% [markdown]
# Q23.
# Print all key-value pairs using items().

# %%
marks.items()
# Out:
# dict_items([('A', 85), ('B', 92), ('C', 76)])

# %% [markdown]
# Q24.
# Count how many values are greater than 50.

# %%
count = sum(1 for mark in marks.values() if mark > 50)
print(count)
# Out:
# 3

# %% [markdown]
# Q25.
# Print only students who scored above 80.

# %%
student = list( key  for key,mark in marks.items() if mark > 80)
print(student)
# Out:
# ['A', 'B']

# %% [markdown]
# Q26.
# Calculate the average of all values.

# %%
average = sum(mark for mark in marks.values())/ len(marks)
print(average)
# Out:
# 84.33333333333333

# %% [markdown]
# Q27.
# Count how many keys begin with the letter "A".

# %%
student = sum( 1  for key in marks.keys() if key.startswith("A"))
print(student)
# Out:
# 1

# %% [markdown]
# Q28.
# Explain the use of
# keys()
#
# The keys() method returns all the keys in a dictionary.
#
# Q29.
# Explain the use of
# values()
#
# The values() method returns all the values in a dictionary.
#
# Q30.
# Explain the use of
# items()
#
# The items() method returns both keys and values as tuples.
#
# Q31.
# Explain the use of
# pop()
#
# The pop() method removes a specified key and returns its value.
#
# Q32.
# Explain the use of
# popitem()
#
# The popitem() method removes and returns the last inserted key-value pair.
#
#
# Q33.
# Explain the use of
# update()
#
# The update() method adds new key-value pairs or updates existing ones.
#
# Q34.
# Explain the use of
# setdefault()
#
# The setdefault() method returns the value of a key. If the key does not exist, it inserts the key with the specified default value.
#
# Q35.
# Explain the use of
# fromkeys()
#
# The fromkeys() method creates a new dictionary using the given keys and assigns the same default value to each key.

# %% [markdown]
# Q36.
# Count the frequency of each character in a string.
# Example
# Input:
# banana
#
# Expected Output:
# {
# 'b':1,
# 'a':3,
# 'n':2
# }

# %%
freq = {}
for i in "banana":
    if i in freq:
        freq[i] = freq[i] + 1
    else:
        freq[i] = 1

for i in freq.items():
    print(i)
# Out:
# ('b', 1)
# ('a', 3)
# ('n', 2)

# %% [markdown]
# Q37.
# Count the frequency of words in a sentence.
# Example
# Input
# I love Python and I love AI
# Expected Output
# {
# 'I':2,
# 'love':2,
# 'Python':1,
# 'and':1,
# 'AI':1
# }

# %%
words = "I love Python and I love AI"
word = list( w for w in words.split(' '))
freq = {}
for i in word:
    if i in freq:
        freq[i] = freq[i] + 1
    else:
        freq[i] = 1

for i in freq.items():
    print(i)
# Out:
# ('I', 2)
# ('love', 2)
# ('Python', 1)
# ('and', 1)
# ('AI', 1)

# %% [markdown]
# Q38.
# Reverse a dictionary.
# Example
# {'A':1,'B':2}
# Expected Output
# {1:'A',2:'B'}

# %%
d = {'A':1,'B':2}
rev = { value : key for key , value in d.items()}
print(rev)
# Out:
# {1: 'A', 2: 'B'}

# %% [markdown]
# Q39.
# Find duplicate values in a dictionary.

# %%
marks = {
    "Alice": 90,
    "Bob": 85,
    "Charlie": 90,
    "David": 70,
    "Eva": 85
}

duplicates = []

for value in marks.values():
    if list(marks.values()).count(value) > 1:
        if value not in duplicates:
            duplicates.append(value)

print(duplicates)
# Out:
# [90, 85]

# %% [markdown]
# Q40.
# Sort a dictionary based on keys.

# %%
sor = dict(sorted(marks.items()))
sor
# Out:
# {'Alice': 90, 'Bob': 85, 'Charlie': 90, 'David': 70, 'Eva': 85}

# %% [markdown]
# Q41.
# Sort a dictionary based on values.

# %%
sor_val = dict(sorted(marks.items() , key= lambda item: item[1]))
sor_val
# Out:
# {'David': 70, 'Bob': 85, 'Eva': 85, 'Alice': 90, 'Charlie': 90}

# %% [markdown]
# Q42.
# Create a dictionary comprehension to generate
# {
# 1:1,
# 2:4,
# 3:9,
# 4:16,
# 5:25
# }

# %%
squares = {x: x**2 for x in range(1, 6)}

print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# Q43.
# Create a dictionary containing cubes from 1 to 10 using dictionary comprehension.

# %%
cube = {x: x**3 for x in range(1, 11)}
print(cube)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}

# %% [markdown]
# Q44.
# Convert two lists into a dictionary using dictionary comprehension.

# %%
keys = ['A', 'B', 'C', 'D']
values = [1, 2, 3, 4]

result = {keys[i]: values[i] for i in range(len(keys))}

print(result)
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4}

# %% [markdown]
# Q45.
# Create a dictionary that stores numbers from 1–20 and labels each as "Even" or "Odd".
# Expected output
# {
# 1:"Odd",
# 2:"Even",
# 3:"Odd",
# ...
# }

# %%
result = {i: "Even" if i % 2 == 0 else "Odd" for i in range(1, 21)}

print(result)
# Out:
# {1: 'Odd', 2: 'Even', 3: 'Odd', 4: 'Even', 5: 'Odd', 6: 'Even', 7: 'Odd', 8: 'Even', 9: 'Odd', 10: 'Even', 11: 'Odd', 12: 'Even', 13: 'Odd', 14: 'Even', 15: 'Odd', 16: 'Even', 17: 'Odd', 18: 'Even', 19: 'Odd', 20: 'Even'}

# %% [markdown]
# Q46.
# Create a dictionary to store details of three students.
# Example
# students={
# 101:{ "Name":"John", "Age":20 },
# 102:{ "Name":"Alice", "Age":21}
# }

# %%
students={
101:{ "Name":"John", "Age":20 },
102:{ "Name":"Alice", "Age":21},
103:{ "Name":"dale", "Age":21}
}
print(students)
# Out:
# {101: {'Name': 'John', 'Age': 20}, 102: {'Name': 'Alice', 'Age': 21}, 103: {'Name': 'dale', 'Age': 21}}

# %% [markdown]
# Q47.
# Print details of student 102.

# %%
print(students[102])
# Out:
# {'Name': 'Alice', 'Age': 21}

# %% [markdown]
# Q48.
# Update the age of student 101.

# %%
students[101]["Age"] = 23
print(students[101])
# Out:
# {'Name': 'John', 'Age': 23}

# %%
mark = {101 : 75, 102 : 50, 103 : 98}
for roll, student in students.items():
    if roll in mark:
        students[roll]["Mark"] = mark[roll]

print(students)
# Out:
# {101: {'Name': 'John', 'Age': 23, 'Mark': 75}, 102: {'Name': 'Alice', 'Age': 21, 'Mark': 50}, 103: {'Name': 'dale', 'Age': 21, 'Mark': 98}}

# %% [markdown]
# Q50.
# Print all student details using nested loops.

# %%
for roll , student in students.items():
    for s, v in student.items():
        print( s , ' : ', v)
# Out:
# Name  :  John
# Age  :  23
# Mark  :  75
# Name  :  Alice
# Age  :  21
# Mark  :  50
# Name  :  dale
# Age  :  21
# Mark  :  98

# %% [markdown]
# Q51.
# Given
# sales={
# "Jan":2500,
# "Feb":3000,
# "Mar":2700,
# "Apr":4000
# }
# Find the month with the highest sales.

# %%
sales={
"Jan":2500,
"Feb":3000,
"Mar":2700,
"Apr":4000
}
max1 = max(sales.values())
month  = list( i for i,val in sales.items() if max(sales.values()) == val )
print(month)
# Out:
# ['Apr']

# %% [markdown]
# Q52.
# Create a dictionary from a sentence where each word is mapped to its length.
# Example
# Python is amazing
# EXPECTED Output
# {
# 'Python':6,
# 'is':2,
# 'amazing':7
# }

# %%
letter  =  "Python is amazing"
list1 = list(letter.split(' '))
dic = {}
for i in list1:
    dic[i] = len(i)

print(dic)
# Out:
# {'Python': 6, 'is': 2, 'amazing': 7}

# %% [markdown]
# Q53.
# Given
# inventory={
# "Pen":25,
# "Pencil":50,
# "Eraser":15
# }
# Reduce every item's quantity by 5.

# %%
inventory={
"Pen":25,
"Pencil":50,
"Eraser":15
}

inventory = { key : value - 5  for key, value in inventory.items() }
print(inventory)
# Out:
# {'Pen': 20, 'Pencil': 45, 'Eraser': 10}

# %% [markdown]
# Q54.
# Merge dictionaries and, if duplicate keys exist, add their values.
# Example
# d1={"A":10,"B":20}
# d2={"B":15,"C":5}
#
# Expected Output
# {"A":10,"B":35,"C":5}

# %%
d1={"A":10,"B":20}
d2={"B":15,"C":5}
d3 = {}
for d1k, d1v in d1.items():
    if d1k in d2:
        d2[d1k] = d1v + d2[d1k]
    else:
        d2[d1k] = d1v
        
d2
# Out:
# {'B': 35, 'C': 5, 'A': 10}

# %% [markdown]
# Q55.
# Create a phonebook using dictionaries that allows the user to:
# Add a contact
# Search for a contact
# Update a contact
# Delete a contact
# Display all contacts
# Exit the program

# %%
phonebook = {}

while True:
    print("\n===== PHONEBOOK =====")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Update Contact")
    print("4. Delete Contact")
    print("5. Display All Contacts")
    print("6. Exit")

    choice = input("Enter your choice: ")

    
    if choice == "1":
        name = input("Enter name: ")
        phone = input("Enter phone number: ")

        phonebook[name] = phone
        print("Contact added successfully!")

    
    elif choice == "2":
        name = input("Enter name to search: ")

        if name in phonebook:
            print("Phone:", phonebook[name])
        else:
            print("Contact not found.")

   
    
    elif choice == "3":
        name = input("Enter name to update: ")

        if name in phonebook:
            phone = input("Enter new phone number: ")
            phonebook[name] = phone
            print("Contact updated successfully!")
        else:
            print("Contact not found.")

    
    elif choice == "4":
        name = input("Enter name to delete: ")

        if name in phonebook:
            del phonebook[name]
            print("Contact deleted successfully!")
        else:
            print("Contact not found.")

    
    elif choice == "5":
        if phonebook:
            print("\nContacts:")

            for name, phone in phonebook.items():
                print(name, ":", phone)
        else:
            print("Phonebook is empty.")

   
    elif choice == "6":
        print("Exiting phonebook...")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# ===== PHONEBOOK =====
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice:  1
# Enter name:  selva
# Enter phone number:  12345678
# Contact added successfully!
#
# ===== PHONEBOOK =====
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice:  2
# Enter name to search:  selva
# Phone: 12345678
#
# ===== PHONEBOOK =====
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice:  3
# Enter name to update:  selva
# Enter new phone number:  123456789
# Contact updated successfully!
#
# ===== PHONEBOOK =====
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# Enter your choice:  6
# Exiting phonebook...
